# %% [markdown]
# This BLASTNet Tutorial is written by Wai Tong Chung. More info visit https://blastnet.github.io
#
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
#
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
#
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Citations

# %% [markdown]
# Please cite the following when publishing based on this dataset:
#
# 1. Appl. Energy in Combust. Sci. Paper: https://doi.org/10.1016/j.jaecs.2022.100087
# 2. ICML W. Paper: https://openreview.net/forum?id=LxGTZM7L6qn
# 3. Dataset citation: https://doi.org/10.5281/zenodo.7242864

# %% [markdown]
# # Import libs and set data path

# %%
import numpy as np # linear algebra
import json
import os
import matplotlib.pyplot as plt

data_path = '/kaggle/input/'+os.popen('ls '+'/kaggle/input/').read().split('\n')[0]+'/'
print("Data path: ",data_path)
# Out:
# Data path:  /kaggle/input/free-propagating-h2-vit-air-li-case-7/

# %% [markdown]
# # Metadata

# %% [markdown]
# We first obtain info on this BLASTNet dataset by reading info.json.

# %%
f = open(data_path + '/info.json')
metadata = json.load(f) #returns a dict

# %% [markdown]
# The metadata is comprised of the global metadata, which provides info on the dataset as a whole:

# %%
for key in metadata['global']:
    print(key," : ",metadata['global'][key])
# Out:
# dataset_id  :  free-propagating-h2-vit-air-li-case-7
# Nxyz  :  [1716, 156, 156]
# snapshots  :  42
# variables  :  ['UX_ms-1', 'UY_ms-1', 'UZ_ms-1', 'P_Pa', 'T_K', 'RHO_kgm-3', 'YH2O', 'YO2', 'YH', 'YOH', 'YH2', 'YHO2', 'YO', 'YH2O2', 'YN2']
# compression  :  None
# grid  :  {'x': './grid/X_m.dat', 'y': './grid/Y_m.dat', 'z': './grid/Z_m.dat'}
# bc  :  {'description': 'Inflow (evaluated with separate HIT) and outflow in x-, and periodic in  y- and z-directions.', 'Uin': 54, 'Tin [K]': 990, 'Inlet mixture': 'H2 and vitiated air at 0.35 equivalence ratio', 'oxidizer mixture': 'Products of H2 and air at 0.43 equivalence ratio at 773K'}
# ic  :  {'Pamb [Pa]': 101300, 'Laminar flame speed [ms-1]': 14.7, 'Re_t [-]': 158, 'Laminar flame thickness [m]': 0.00066, 'Integral lengthscale [mm]': 0.00099, 'Da_ign [-]': 0.08, 'Ka_u [-]': 13.0, 'tau_ign,0 [s]': 0.00055, 'velocity fluctuation [ms-1]': 22.049999999999997}
# doi  :  https://doi.org/10.1016/j.combustflame.2019.07.020
# contributors  :  Bruno Savard
# description  :  Vitiated H2-air Freely Propagating Flame DNS
# chem_thermo_tran  :  {'description': 'FRC and Mixture-Averaged Transport', 'cantera_cti': './chem_thermo_tran/li_h2.cti'}

# %% [markdown]
# And the local metadata which provides info on the individual snapshots. Here, we print some local metadata.

# %%
if len(metadata['local'])>3:
    for file_id in range(3):
        for key in metadata['local'][file_id]:
            print(key," : ",metadata['local'][file_id][key])
        print("----------------------------------")
else:
    file_id = 0
    for key in metadata['local'][file_id]:
        print(key," : ",metadata['local'][file_id][key])
# Out:
# id  :  0
# time [s]  :  5.0048e-05
# UX_ms-1 filename  :  ./data/UX_ms-1_id000.dat
# UY_ms-1 filename  :  ./data/UY_ms-1_id000.dat
# UZ_ms-1 filename  :  ./data/UZ_ms-1_id000.dat
# P_Pa filename  :  ./data/P_Pa_id000.dat
# T_K filename  :  ./data/T_K_id000.dat
# RHO_kgm-3 filename  :  ./data/RHO_kgm-3_id000.dat
# YH2O filename  :  ./data/YH2O_id000.dat
# YO2 filename  :  ./data/YO2_id000.dat
# YH filename  :  ./data/YH_id000.dat
# YOH filename  :  ./data/YOH_id000.dat
# YH2 filename  :  ./data/YH2_id000.dat
# YHO2 filename  :  ./data/YHO2_id000.dat
# YO filename  :  ./data/YO_id000.dat
# YH2O2 filename  :  ./data/YH2O2_id000.dat
# YN2 filename  :  ./data/YN2_id000.dat
# ----------------------------------
# id  :  1
# time [s]  :  0.00010004
# UX_ms-1 filename  :  ./data/UX_ms-1_id001.dat
# UY_ms-1 filename  :  ./data/UY_ms-1_id001.dat
# UZ_ms-1 filename  :  ./data/UZ_ms-1_id001.dat
# P_Pa filename  :  ./data/P_Pa_id001.dat
# T_K filename  :  ./data/T_K_id001.dat
# RHO_kgm-3 filename  :  ./data/RHO_kgm-3_id001.dat
# YH2O filename  :  ./data/YH2O_id001.dat
# YO2 filename  :  ./data/YO2_id001.dat
# YH filename  :  ./data/YH_id001.dat
# YOH filename  :  ./data/YOH_id001.dat
# YH2 filename  :  ./data/YH2_id001.dat
# YHO2 filename  :  ./data/YHO2_id001.dat
# YO filename  :  ./data/YO_id001.dat
# YH2O2 filename  :  ./data/YH2O2_id001.dat
# YN2 filename  :  ./data/YN2_id001.dat
# ----------------------------------
# id  :  2
# time [s]  :  0.00015012
# UX_ms-1 filename  :  ./data/UX_ms-1_id002.dat
# UY_ms-1 filename  :  ./data/UY_ms-1_id002.dat
# UZ_ms-1 filename  :  ./data/UZ_ms-1_id002.dat
# P_Pa filename  :  ./data/P_Pa_id002.dat
# T_K filename  :  ./data/T_K_id002.dat
# RHO_kgm-3 filename  :  ./data/RHO_kgm-3_id002.dat
# YH2O filename  :  ./data/YH2O_id002.dat
# YO2 filename  :  ./data/YO2_id002.dat
# YH filename  :  ./data/YH_id002.dat
# YOH filename  :  ./data/YOH_id002.dat
# YH2 filename  :  ./data/YH2_id002.dat
# YHO2 filename  :  ./data/YHO2_id002.dat
# YO filename  :  ./data/YO_id002.dat
# YH2O2 filename  :  ./data/YH2O2_id002.dat
# YN2 filename  :  ./data/YN2_id002.dat
# ----------------------------------

# %% [markdown]
# # Grid Information

# %% [markdown]
# Since we're dealing with spatial data let's look at the spatial grid. We first get some details from the metadata.

# %%
Nx,Ny,Nz = metadata['global']['Nxyz']

X_filename = metadata['global']['grid']['x']
Y_filename = metadata['global']['grid']['y']
Z_filename = metadata['global']['grid']['z']

print(X_filename)
print(Y_filename)
print(Z_filename)
# Out:
# ./grid/X_m.dat
# ./grid/Y_m.dat
# ./grid/Z_m.dat

# %% [markdown]
# Now lets load the 3D grid data and obtain their 1D profiles

# %%
#load data
X =  np.fromfile(data_path+X_filename,dtype='<f4')
Y =  np.fromfile(data_path+Y_filename,dtype='<f4')
Z =  np.fromfile(data_path+Z_filename,dtype='<f4')

#get 1d profile
x1d = np.unique(X)
y1d = np.unique(Y)
z1d = np.unique(Z)

# %% [markdown]
# We can use this to plot the dimensions of the grid in 1D.

# %%
fig, axs = plt.subplots(1,3,figsize=(20, 5))
axs[0].plot(x1d)
axs[0].set_xlim([0,len(x1d)])
axs[0].set_ylim([x1d.min(),x1d.max()])
axs[0].set_title('X')
axs[0].set_ylabel('x [m]')
axs[0].set_xlabel('Index i')


axs[1].plot(y1d)
axs[1].set_xlim([0,len(y1d)])
axs[1].set_ylim([y1d.min(),y1d.max()])
axs[1].set_title('Y')
axs[1].set_ylabel('y [m]')
axs[1].set_xlabel('Index j')

axs[2].plot(z1d)
axs[2].set_xlim([0,len(z1d)])
axs[2].set_ylim([z1d.min(),z1d.max()])
axs[2].set_title('Z')
axs[2].set_ylabel('z [m]')
axs[2].set_xlabel('Index k')
# Out:
# Text(0.5, 0, 'Index k')

# %% [markdown]
# # Visualizing a single flowfield

# %% [markdown]
# We now visualizing the a random velocity flowfields using imshow. Here load the file with metadata info with a random number generator.

# %%
#Random number generator
nfile = len(metadata['local'])
file_id = np.random.randint(nfile)

#Load and reshape array
u_filename = metadata['local'][file_id]['UX_ms-1 filename']
u = np.fromfile(data_path+u_filename,dtype='<f4')
u = u.reshape(Nx,Ny,Nz)

print("Array shape: ")
print(u.shape)
# Out:
# Array shape:
# (1716, 156, 156)

# %% [markdown]
# Next we plot files in the x-,y-, and z- planes. Note that the arrays are in ijk order.

# %%
align='vertical'
figsize = np.array((10, 5))
if align == 'vertical':
    fig, axs = plt.subplots(3,1,figsize=figsize.T)

    imX = axs[0].imshow(u[int(len(x1d)/2),:,:].T,origin='lower',extent = [y1d.min(), y1d.max(),z1d.min(),z1d.max()])
    axs[0].set_xlabel('y [m]')
    axs[0].set_ylabel('z [m]')

    imY = axs[1].imshow(u[:,int(len(y1d)/2),:].T,origin='lower',extent = [x1d.min(), x1d.max(),z1d.min(),z1d.max()])
    axs[1].set_xlabel('x [m]')
    axs[1].set_ylabel('z [m]')

    imZ = axs[2].imshow(u[:,:,int(len(z1d)/2)].T,origin='lower',extent = [x1d.min(), x1d.max(),y1d.min(),y1d.max()])
    axs[2].set_xlabel('x [m]')
    axs[2].set_ylabel('y [m]')
else:
    fig, axs = plt.subplots(1,3,figsize=figsize)
    imX = axs[0].imshow(u[int(len(x1d)/2),:,:],origin='lower',extent = [z1d.min(),z1d.max(),y1d.min(), y1d.max()])
    axs[0].set_ylabel('y [m]')
    axs[0].set_xlabel('z [m]')

    imY = axs[1].imshow(u[:,int(len(y1d)/2),:],origin='lower',extent = [z1d.min(),z1d.max(),x1d.min(), x1d.max()])
    axs[1].set_ylabel('x [m]')
    axs[1].set_xlabel('z [m]')

    imZ = axs[2].imshow(u[:,:,int(len(z1d)/2)],origin='lower',extent = [y1d.min(),y1d.max(),x1d.min(), x1d.max()])
    axs[2].set_ylabel('x [m]')
    axs[2].set_xlabel('y [m]')

plt.colorbar(imX, ax=axs[0])
plt.colorbar(imY, ax=axs[1])
plt.colorbar(imZ, ax=axs[2])
plt.tight_layout()

print('File Id = '+str(metadata['local'][file_id]['id']))
print('t = '+str(metadata['local'][file_id]['time [s]'])+' s')
# Out:
# File Id = 0
# t = 5.0048e-05 s

# %% [markdown]
# # Browse the dataset

# %% [markdown]
# Now that we've visualized and loaded the data, we can now browse for more info on the data.

# %% [markdown]
# We start by printing the max and min of the flowfields we have:

# %%
from prettytable import PrettyTable
#Random number generator
file_id = np.random.randint(nfile)
local_meta = metadata['local'][file_id]

#Print min max
tab = PrettyTable(['Var.','Min', 'Max'])
for key in local_meta:
    if 'filename' in key:
        field = np.fromfile(data_path+local_meta[key],dtype='<f4').reshape(Nx,Ny,Nz)
        tab.add_row([key.replace(' filename',''),field.min(), field.max() ])
print(tab)
# Out:
# +-----------+----------------+---------------+
# |    Var.   |      Min       |      Max      |
# +-----------+----------------+---------------+
# |  UX_ms-1  |   -65.49379    |   202.65613   |
# |  UY_ms-1  |   -94.57308    |   102.59922   |
# |  UZ_ms-1  |   -86.89999    |   105.72879   |
# |    P_Pa   |    98400.05    |   104324.734  |
# |    T_K    |   988.62524    |   1814.4435   |
# | RHO_kgm-3 |    0.175772    |   0.30718884  |
# |    YH2O   |  0.051437143   |   0.14420246  |
# |    YO2    |   0.11184666   |    0.218087   |
# |     YH    |  5.773882e-14  |  0.0008200354 |
# |    YOH    | 1.8045646e-14  |  0.008567525  |
# |    YH2    | 3.2103402e-05  |  0.009600021  |
# |    YHO2   | -1.3604223e-09 | 0.00019889614 |
# |     YO    |  1.695425e-14  |  0.007836898  |
# |   YH2O2   | -2.1934303e-09 | 2.1106756e-05 |
# |    YN2    |   0.7168871    |   0.7282936   |
# +-----------+----------------+---------------+

# %% [markdown]
# Now let's visualize what the flowfields look like from start and finish:

# %%
#Input params
file_id = 0 
nrows = 3
figsize = (15, 30)

#Get Number of variables
nvar = len(metadata['global']['variables'])
print("Plotting "+str(nvar)+" variables in " + str(nrows) + " rows")

#Print file info:
local_meta = metadata['local'][file_id]
print('File Id = '+str(metadata['local'][file_id]['id']))
print('t='+str(metadata['local'][file_id]['time [s]'])+' s')


#Plot all scalars
nplots = [nrows,int(nvar/nrows)]    
fig, axs = plt.subplots(nplots[0],nplots[1],figsize=figsize,sharex=True,sharey=True)
count= 0
for key in local_meta:
    if 'filename' in key:
        field = np.fromfile(data_path+local_meta[key],dtype='<f4').reshape(Nx,Ny,Nz)
        if nplots[0]>1:
            i = int(count/nplots[1])
            j = count - i*nplots[1]
            im = axs[i,j].imshow(field[:,:,int(len(z1d)/2)],origin='lower',
                   extent =  np.array([y1d.min(),y1d.max(),x1d.min(), x1d.max()])*1000)
            plt.colorbar(im, ax=axs[i, j])
            axs[i,j].set_title(key.replace(' filename',''))
        else:
            im = axs[count].imshow(field[:,:,int(len(z1d)/2)],origin='lower',
               extent = np.array([y1d.min(),y1d.max(),x1d.min(), x1d.max()])*1000)
            plt.colorbar(im, ax=axs[count])
            axs[count].set_title(key.replace(' filename',''))
        count=count+1
_ = fig.text(0.04, 0.5, 'x [mm]', va='center', rotation='vertical')
_ = fig.text(0.5, 0.04, 'y [mm]', ha='center')
# Out:
# Plotting 15 variables in 3 rows
# File Id = 0
# t=5.0048e-05 s

# %%
#Input params
file_id = nfile-1 
nrows = 3
figsize = (15, 30)

#Get Number of variables
nvar = len(metadata['global']['variables'])
print("Plotting "+str(nvar)+" variables in " + str(nrows) + " rows")

#Print file info:
local_meta = metadata['local'][file_id]
print('File Id = '+str(metadata['local'][file_id]['id']))
print('t = '+str(metadata['local'][file_id]['time [s]'])+' s')


#Plot all scalars
nplots = [nrows,int(nvar/nrows)]    
fig, axs = plt.subplots(nplots[0],nplots[1],figsize=figsize,sharex=True,sharey=True)
count= 0
for key in local_meta:
    if 'filename' in key:
        field = np.fromfile(data_path+local_meta[key],dtype='<f4').reshape(Nx,Ny,Nz)
        if nplots[0]>1:
            i = int(count/nplots[1])
            j = count - i*nplots[1]
            im = axs[i,j].imshow(field[:,:,int(len(z1d)/2)],origin='lower',
                   extent =  np.array([y1d.min(),y1d.max(),x1d.min(), x1d.max()])*1000)
            plt.colorbar(im, ax=axs[i, j])
            axs[i,j].set_title(key.replace(' filename',''))
        else:
            im = axs[count].imshow(field[:,:,int(len(z1d)/2)],origin='lower',
               extent = np.array([y1d.min(),y1d.max(),x1d.min(), x1d.max()])*1000)
            plt.colorbar(im, ax=axs[count])
            axs[count].set_title(key.replace(' filename',''))
        count=count+1
_ = fig.text(0.04, 0.5, 'x [mm]', va='center', rotation='vertical')
_ = fig.text(0.5, 0.04, 'y [mm]', ha='center')
# Out:
# Plotting 15 variables in 3 rows
# File Id = 41
# t = 0.0021 s
